# %% [markdown]
# <a href="https://colab.research.google.com/github/Chilese/Python_FinancialMarket/blob/main/Biblioteca_Quantstats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install quantstats

# %%
import quantstats as qs

# %%
stock = qs.utils.download_returns('AMZN')
qs.plots.snapshot(stock, title = "Desempenho Amazon")
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.

# %%
qs.reports.html(stock, 
                "SPY",
                output= 'file-path/file-name.html',
                download_filename= 'Relatorio.html')
